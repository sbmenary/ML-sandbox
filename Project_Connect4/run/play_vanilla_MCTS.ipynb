# %% [markdown]
# #  Play bot (vanilla MCTS)
#
# ---
#
# Author: S. Menary [sbmenary@gmail.com]
#
# Date  : 2023-01-03, last edit 2023-01-19
#
# Brief : Play a game of Connect 4 against bot that uses simple MCTS with no machine learning.
#
# ---

# %% [markdown]
# ## Imports
#
# - Import key Python and PyPI packages and print their versions for reproducibility.
# - Import the required Connect 4 game, bot and utility objects from our framework
#
# ---

# %%
##=====================================##
##  All imports should be placed here  ##
##=====================================##

##  Python core libs
import sys

##  PyPI libs
import numpy as np
import tensorflow as tf

##  Local packages
from connect4.utils import DebugLevel
from connect4.game  import GameBoard
from connect4.MCTS  import PolicyStrategy
from connect4.bot   import Bot_VanillaMCTS

# %%
##======================================##
##  Print versions for reproducibility  ##
##======================================##

print(f"    Python version is {sys.version}")
print(f"     Numpy version is {np.__version__}")
print(f"Tensorflow version is {tf.__version__}")
# Out:
#     Python version is 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:25:29) [Clang 14.0.6 ]
#      Numpy version is 1.23.2
# Tensorflow version is 2.11.0

# %% [markdown]
# ---
#
# ## Play a game vs bot
#
# Play a game of connect 4 against our bot!
#
# The `GameBoard` object is used as a Connect 4 game environment. It may be updated using a command like `game_board.apply_action(column_index)`. We can create a simple ASCII representation of our game board using `print(game_board)`. See `help(GameBoard)` for more useful manipulation methods.
#
# The `Bot_VanillaMCTS` object is used to apply bot actions using vanilla MCTS. Call `bot.take_move(game_board, duration)` to run MCTS for `duration` seconds and then play a bot move. Turning up the `duration` parameter will improve the bot by allowing it to search for longer.
#
# The option `PolicyStrategy.GREEDY_POSTERIOR_VALUE` commands the bot to choose the action that maximises the action values estimated using MCTS. To act greedily over the posterior policy instead, use `PolicyStrategy.GREEDY_POSTERIOR_POLICY`. For a stochastic approach, use `PolicyStrategy.SAMPLE_POSTERIOR_POLICY`.
#
# ---

# %%
##=====================##
##  Create a new game  ##
##=====================##

game_board = GameBoard()
bot        = Bot_VanillaMCTS(policy_strategy=PolicyStrategy.GREEDY_POSTERIOR_VALUE)
print(game_board)
# Out:
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE

# %% [markdown]
# ---
#
# Now play moves until the game is complete!
#
# ---

# %%
##===============##
##  Take moves!  ##
##===============##

##  Select our move
column_idx = 2

##  Apply our move as Player X
game_board.apply_action(column_idx)
print(game_board)

##  Apply the responding bot move move as Player O
if not game_board.get_result() :
    bot.take_move(game_board, duration=5, debug_lvl=DebugLevel.LOW)
    print(game_board)
# Out:
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | X | . | . | . | . |
# | . | O | O | O | . | . | . |
# | . | X | X | O | O | X | . |
# | X | O | X | X | X | O | . |
# | X | O | X | X | O | O | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.091  0.631   0.640   0.690   1.000   0.687   1.000
# Visit counts are:   22      130     139     168     1661    166     1660
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | X | . | . | . | . |
# | . | O | O | O | O | . | . |
# | . | X | X | O | O | X | . |
# | X | O | X | X | X | O | . |
# | X | O | X | X | O | O | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: O

# %% [markdown]
# ---
#
# ## Bot-vs-bot game
#
# Let's watch the bot play itself!
#
# ---

# %%
##========================##
##  Play bot-vs-bot game  ##
##========================##


##  Set up and display game
game_board = GameBoard()
result     = game_board.get_result()
print(game_board)

##  Keep playing moves until the game concludes
while not result :
    bot.take_move(game_board, duration=5, debug_lvl=DebugLevel.LOW)
    result = game_board.get_result()
    print(game_board)
# Out:
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.111  0.200   0.191   0.298   -0.014  0.258   0.047
# Visit counts are:   54      155     152     265     69      186     86
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | X | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.227  -0.311  -0.193  -0.220  -0.470  -0.330  -0.277
# Visit counts are:   172     119     202     177     66      109     137
# Selecting action 2
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | O | X | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.033   -0.019  0.328   0.379   0.248   0.250   0.270
# Visit counts are:   61      53      192     253     133     136     148
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | X | . | . | . |
# | . | . | O | X | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.443  -0.474  -0.255  -0.194  -0.512  -0.789  -0.431
# Visit counts are:   106     95      231     392     82      38      109
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | . | X | . | . | . |
# | . | . | O | X | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.282   0.089   0.308   0.212   -0.163  0.236   0.127
# Visit counts are:   206     90      240     151     43      165     102
# Selecting action 2
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | X | X | . | . | . |
# | . | . | O | X | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.369  -0.923  -0.165  -0.226  -0.402  -0.294  -0.328
# Visit counts are:   111     26      315     217     97      153     131
# Selecting action 2
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | O | O | . | . | . |
# | . | . | X | X | . | . | . |
# | . | . | O | X | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.253   0.000   0.179   0.220   -0.174  0.223   0.310
# Visit counts are:   166     74      145     173     46      175     290
# Selecting action 6
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | O | O | . | . | . |
# | . | . | X | X | . | . | . |
# | . | . | O | X | . | . | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.684  -0.429  -0.193  -0.105  -0.295  -0.152  -0.425
# Visit counts are:   38      77      207     361     129     224     80
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | O | O | . | . | . |
# | . | . | X | X | . | . | . |
# | . | . | O | X | . | . | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.043  -0.100  0.012   0.206   0.317   0.387   0.059
# Visit counts are:   69      60      83      189     357     424     102
# Selecting action 5
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | O | O | . | . | . |
# | . | . | X | X | . | . | . |
# | . | . | O | X | . | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.659  -0.758  -0.609  -0.457  0.041   -0.547  -0.508
# Visit counts are:   41      33      46      70      975     53      61
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | O | O | . | . | . |
# | . | . | X | X | . | . | . |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.064  -0.205  -0.144  -0.064  0.110   -0.027  -0.221
# Visit counts are:   156     88      111     156     445     187     86
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | O | O | . | . | . |
# | . | . | X | X | X | . | . |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.591  -0.565  -0.542  -0.438  -0.438  0.072   -0.909
# Visit counts are:   44      46      48      64      64      1060    22
# Selecting action 5
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | O | O | . | . | . |
# | . | . | X | X | X | O | . |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.181  -0.309  -0.207  -0.081  0.045   -0.083  -0.414
# Visit counts are:   127     81      111     209     471     205     58
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | O | O | X | . | . |
# | . | . | X | X | X | O | . |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.028   -0.455  -0.008  0.259   0.021   0.138   -0.306
# Visit counts are:   144     33      123     594     141     253     49
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | O | O | X | . | . |
# | . | . | X | X | X | O | . |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.488  -0.696  -0.593  -0.050  -0.488  -0.520  -0.506
# Visit counts are:   82      46      59      974     82      75      77
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | X | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | O | O | X | . | . |
# | . | . | X | X | X | O | . |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.038  -0.562  -0.105  0.182   0.023   -0.100
# Visit counts are:   156     32      114     665     213     120
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | . | . | X | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | . | O | O | . | . |
# | . | . | O | O | X | . | . |
# | . | . | X | X | X | O | . |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.211  -0.366  -0.195  -0.252  -0.209  -0.036
# Visit counts are:   180     93      195     147     172     548
# Selecting action 6
# +---+---+---+---+---+---+---+
# | . | . | . | X | . | . | . |
# | . | . | . | O | . | . | . |
# | . | . | . | O | O | . | . |
# | . | . | O | O | X | . | . |
# | . | . | X | X | X | O | X |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.063   -0.500  0.009   0.101   -0.056  0.009
# Visit counts are:   318     40      230     407     161     220
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | . | . | X | . | . | . |
# | . | . | . | O | O | . | . |
# | . | . | . | O | O | . | . |
# | . | . | O | O | X | . | . |
# | . | . | X | X | X | O | X |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.077  -0.492  -0.260  -0.117  -0.327  -0.064
# Visit counts are:   403     63      146     308     110     436
# Selecting action 6
# +---+---+---+---+---+---+---+
# | . | . | . | X | . | . | . |
# | . | . | . | O | O | . | . |
# | . | . | . | O | O | . | . |
# | . | . | O | O | X | . | X |
# | . | . | X | X | X | O | X |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.524  -0.579  -0.434  -0.579  -0.434  0.172
# Visit counts are:   42      38      53      38      53      1358
# Selecting action 6
# +---+---+---+---+---+---+---+
# | . | . | . | X | . | . | . |
# | . | . | . | O | O | . | . |
# | . | . | . | O | O | . | O |
# | . | . | O | O | X | . | X |
# | . | . | X | X | X | O | X |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.368  -0.540  -0.355  -0.368  -0.579  -0.137
# Visit counts are:   171     87      183     171     76      860
# Selecting action 6
# +---+---+---+---+---+---+---+
# | . | . | . | X | . | . | . |
# | . | . | . | O | O | . | X |
# | . | . | . | O | O | . | O |
# | . | . | O | O | X | . | X |
# | . | . | X | X | X | O | X |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.010   -0.487  0.217   0.107   -0.373  -0.098
# Visit counts are:   200     39      853     363     51      122
# Selecting action 2
# +---+---+---+---+---+---+---+
# | . | . | . | X | . | . | . |
# | . | . | . | O | O | . | X |
# | . | . | O | O | O | . | O |
# | . | . | O | O | X | . | X |
# | . | . | X | X | X | O | X |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.146  -0.519  -0.289  -0.112  -0.549  -0.176
# Visit counts are:   478     79      194     525     71      386
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | . | . | X | X | . | . |
# | . | . | . | O | O | . | X |
# | . | . | O | O | O | . | O |
# | . | . | O | O | X | . | X |
# | . | . | X | X | X | O | X |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.245   -0.515  0.102   -0.515  0.414
# Visit counts are:   641     33      236     33      1064
# Selecting action 6
# +---+---+---+---+---+---+---+
# | . | . | . | X | X | . | O |
# | . | . | . | O | O | . | X |
# | . | . | O | O | O | . | O |
# | . | . | O | O | X | . | X |
# | . | . | X | X | X | O | X |
# | . | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.731  -0.899  -0.828  -0.893
# Visit counts are:   2272    396     697     412
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | . | . | X | X | . | O |
# | . | . | . | O | O | . | X |
# | . | . | O | O | O | . | O |
# | . | . | O | O | X | . | X |
# | . | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.835   -0.571  -0.050  -0.571
# Visit counts are:   3594    28      141     28
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | . | . | X | X | . | O |
# | . | . | . | O | O | . | X |
# | . | . | O | O | O | . | O |
# | . | . | O | O | X | . | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.852  -0.938  -0.895  -0.942
# Visit counts are:   2337    802     1275    765
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | . | . | X | X | . | O |
# | . | . | . | O | O | . | X |
# | . | . | O | O | O | . | O |
# | X | . | O | O | X | . | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.933   -0.500  -0.268  -0.462
# Visit counts are:   6205    24      41      26
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | . | . | X | X | . | O |
# | . | . | . | O | O | . | X |
# | O | . | O | O | O | . | O |
# | X | . | O | O | X | . | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.910  -0.961  -0.927  -0.961
# Visit counts are:   2502    1232    1923    1232
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | . | . | X | X | . | O |
# | X | . | . | O | O | . | X |
# | O | . | O | O | O | . | O |
# | X | . | O | O | X | . | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.990   -0.400  -0.029  -0.400
# Visit counts are:   14372   20      35      20
# Selecting action 0
# +---+---+---+---+---+---+---+
# | O | . | . | X | X | . | O |
# | X | . | . | O | O | . | X |
# | O | . | O | O | O | . | O |
# | X | . | O | O | X | . | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.995  -0.993  -0.995
# Visit counts are:   8315    8855    8315
# Selecting action 2
# +---+---+---+---+---+---+---+
# | O | . | . | X | X | . | O |
# | X | . | X | O | O | . | X |
# | O | . | O | O | O | . | O |
# | X | . | O | O | X | . | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.556  0.999   -0.474
# Visit counts are:   18      35636   19
# Selecting action 2
# +---+---+---+---+---+---+---+
# | O | . | O | X | X | . | O |
# | X | . | X | O | O | . | X |
# | O | . | O | O | O | . | O |
# | X | . | O | O | X | . | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -1.000  -0.999
# Visit counts are:   25717   26777
# Selecting action 5
# +---+---+---+---+---+---+---+
# | O | . | O | X | X | . | O |
# | X | . | X | O | O | . | X |
# | O | . | O | O | O | . | O |
# | X | . | O | O | X | X | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -1.000  1.000
# Visit counts are:   12      83515
# Selecting action 5
# +---+---+---+---+---+---+---+
# | O | . | O | X | X | . | O |
# | X | . | X | O | O | . | X |
# | O | . | O | O | O | O | O |
# | X | . | O | O | X | X | X |
# | O | . | X | X | X | O | X |
# | X | . | O | X | O | X | X |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: O
