# %% [markdown]
# #  Play bot (neural MCTS)
#
# ---
#
# Author: S. Menary [sbmenary@gmail.com]
#
# Date  : 2023-01-18, last edit 2023-01-19
#
# Brief : Play a game of Connect 4 against bot that uses MCTS with a learned policy/value function.
#
# ---

# %% [markdown]
# ## Imports
#
# - Import key Python and PyPI packages and print their versions for reproducibility.
# - Import the required Connect 4 game, bot and utility objects from our framework
#
# ---

# %%
##=====================================##
##  All imports should be placed here  ##
##=====================================##

##  Python core libs
import sys

##  PyPI libs
import numpy as np
import tensorflow as tf

##  Local packages
from connect4.utils  import DebugLevel
from connect4.game   import GameBoard
from connect4.MCTS   import PolicyStrategy
from connect4.bot    import Bot_NeuralMCTS
from connect4.neural import load_model

# %%
##======================================##
##  Print versions for reproducibility  ##
##======================================##

print(f"    Python version is {sys.version}")
print(f"     Numpy version is {np.__version__}")
print(f"Tensorflow version is {tf.__version__}")
# Out:
#     Python version is 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:25:29) [Clang 14.0.6 ]
#      Numpy version is 1.23.2
# Tensorflow version is 2.11.0

# %% [markdown]
# ---
#
# ## Play a game vs bot
#
# Play a game of connect 4 against our bot!
#
# The `GameBoard` object is used as a Connect 4 game environment. It may be updated using a command like `game_board.apply_action(column_index)`. We can create a simple ASCII representation of our game board using `print(game_board)`. See `help(GameBoard)` for more useful manipulation methods.
#
# The `Bot_NeuralMCTS` object is used to apply bot actions using neural MCTS. Call `bot.take_move(game_board, duration)` to run MCTS for `duration` seconds and then play a bot move. Turning up the `duration` parameter will improve the bot by allowing it to search for longer.
#
# The option `PolicyStrategy.GREEDY_POSTERIOR_POLICY` commands the bot to choose the action with the highest posterior policy estimated using MCTS. To act greedily over the action values instead, use `PolicyStrategy.GREEDY_POSTERIOR_VALUES`. For a stochastic approach, use `PolicyStrategy.SAMPLE_POSTERIOR_POLICY`.
#
# You may also skip the MCTS entirely by using `duration=0` and selecting actions using the _prior_ evaluations. In particular:
# - `PolicyStrategy.GREEDY_PRIOR_POLICY` means we select the action that maximises the policy evaluated using a single neural network pass.
# - `PolicyStrategy.GREEDY_PRIOR_VALUES` means we select the action that maximises the value evaluated using a single neural network pass on each of the child nodes.
# - `PolicyStrategy.SAMPLE_PRIOR_POLICY` means we sample from the policy evaluated using a single neural network pass.
#
# ---

# %%
##=========================================##
##  Load our neural policy/value function  ##
##=========================================##

##  Configure which model to load
model_name = "../models/.neural_model_v4.h5"

##  Load this model
model = load_model(model_name)

# %%
##=====================##
##  Create a new game  ##
##=====================##

game_board = GameBoard()
bot        = Bot_NeuralMCTS(model, policy_strategy=PolicyStrategy.GREEDY_POSTERIOR_VALUE)
print(game_board)
# Out:
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE

# %% [markdown]
# ---
#
# Now play moves until the game is complete!
#
# ---

# %%
##===============##
##  Take moves!  ##
##===============##

##  Select our move
column_idx = 1

##  Apply our move as Player X
game_board.apply_action(column_idx)
print(game_board)

##  Apply the responding bot move move as Player O
if not game_board.get_result() :
    bot.take_move(game_board, duration=5, debug_lvl=DebugLevel.LOW)
    print(game_board)
# Out:
# +---+---+---+---+---+---+---+
# | X | . | X | X | O | . | . |
# | O | . | X | O | O | . | . |
# | X | . | O | X | X | X | . |
# | X | X | O | O | X | X | . |
# | O | O | X | O | X | O | O |
# | O | O | X | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: X

# %% [markdown]
# ---
#
# ## Bot-vs-bot game
#
# Let's watch the bot play itself!
#
# ---

# %%
##========================##
##  Play bot-vs-bot game  ##
##========================##


##  Set up and display game
game_board = GameBoard()
result     = game_board.get_result()
print(game_board)

##  Keep playing moves until the game concludes
while not result :
    bot.take_move(game_board, duration=5, debug_lvl=DebugLevel.LOW)
    result = game_board.get_result()
    print(game_board)
# Out:
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.654  0.038   0.036   -0.028  0.028   0.096   0.008
# Visit counts are:   1       16      12      261     11      559     2
# Selecting action 5
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.142  -0.156  -0.080  -0.130  0.017   -0.290  -0.087
# Visit counts are:   3       1       192     537     65      1       65
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.033  0.040   -0.034  -0.097  -0.022  -0.025  -0.063
# Visit counts are:   12      517     26      152     133     20      16
# Selecting action 1
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.694  -0.027  -0.069  -0.200  -0.112  -0.227  -0.248
# Visit counts are:   1       745     21      58      27      22      2
# Selecting action 1
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | O | . | . | . | . | . |
# | . | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.330  0.050   -0.254  -0.086  -0.401  -0.146  -0.381
# Visit counts are:   5       819     12      21      5       10      1
# Selecting action 1
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | X | . | . | . | . | . |
# | . | O | . | . | . | . | . |
# | . | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.103  -0.249  -0.043  -0.163  -0.297  0.007   -0.478
# Visit counts are:   17      18      117     32      24      670     1
# Selecting action 5
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | X | . | . | . | . | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.556  -0.730  -0.189  -0.099  -0.044  0.016   -0.555
# Visit counts are:   1       1       5       59      82      736     1
# Selecting action 5
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.930  -0.247  -0.319  -0.400  -0.215  0.042   -0.453
# Visit counts are:   1       11      12      11      15      825     7
# Selecting action 5
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.470  -0.128  -0.356  -0.152  -0.257  0.003   -0.396
# Visit counts are:   3       36      13      48      27      750     5
# Selecting action 5
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | . | . |
# | . | . | . | . | . | X | . |
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.076  -0.057  -0.173  -0.111  -0.335  -0.032  -0.376
# Visit counts are:   54      229     22      52      25      504     8
# Selecting action 5
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.170   -0.029  -0.190  -0.170  -0.003  -0.205
# Visit counts are:   748     33      17      47      46      3
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | X | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.215  -0.096  -0.363  -0.210  -0.188  -0.219
# Visit counts are:   58      622     24      48      86      89
# Selecting action 1
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | X | X | . | . | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.342  -0.038  -0.278  0.091   -0.170  -0.443
# Visit counts are:   3       180     4       720     3       1
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | X | X | . | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.408  -0.349  -0.062  -0.376  -0.677  -0.340
# Visit counts are:   4       12      843     13      28      2
# Selecting action 2
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | X | X | O | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.169   0.046   -0.070  0.067   -0.089  -0.202
# Visit counts are:   93      412     31      335     5       3
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | X | O | . | . | . | O | . |
# | X | X | O | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.212  -0.178  0.038   -0.165  -0.718  -0.572
# Visit counts are:   87      16      773     19      1       3
# Selecting action 2
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | X | O | O | . | . | O | . |
# | X | X | O | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.765  -0.123  -0.075  0.000   -0.584  -0.923
# Visit counts are:   3       64      298     493     1       1
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | X | O | O | X | . | O | . |
# | X | X | O | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.417  -0.198  -0.153  0.045   -0.976  -0.636
# Visit counts are:   48      8       14      790     1       1
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | . | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | O | . | X | . |
# | X | O | O | X | . | O | . |
# | X | X | O | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.727  -0.023  -0.169  -0.204  -0.864  -0.941
# Visit counts are:   1       719     148     14      1       1
# Selecting action 1
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | . | O | . | X | . |
# | X | O | O | X | . | O | . |
# | X | X | O | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.003   -0.104  0.056   -0.002  -0.111  -0.072
# Visit counts are:   133     52      626     33      14      32
# Selecting action 2
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | . | . | . | O | . |
# | . | X | O | O | . | X | . |
# | X | O | O | X | . | O | . |
# | X | X | O | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.268  -0.431  -0.031  -0.130  -0.653  -0.082
# Visit counts are:   4       2       881     2       1       4
# Selecting action 2
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | X | . | . | O | . |
# | . | X | O | O | . | X | . |
# | X | O | O | X | . | O | . |
# | X | X | O | X | O | X | . |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.041   0.022   0.019   -0.206  -0.020  0.043
# Visit counts are:   276     237     53      3       16      315
# Selecting action 6
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | X | . | . | O | . |
# | . | X | O | O | . | X | . |
# | X | O | O | X | . | O | . |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.129  -0.737  -0.041  -0.090  -0.684  -0.039
# Visit counts are:   18      1       811     25      1       48
# Selecting action 6
# +---+---+---+---+---+---+---+
# | . | . | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | X | . | . | O | . |
# | . | X | O | O | . | X | . |
# | X | O | O | X | . | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.002   0.008   -0.008  -0.364  -0.899  -0.201
# Visit counts are:   261     599     17      3       1       19
# Selecting action 1
# +---+---+---+---+---+---+---+
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | X | . | . | O | . |
# | . | X | O | O | . | X | . |
# | X | O | O | X | . | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.045   0.018   -0.044  -0.278  -0.087
# Visit counts are:   143     720     39      7       7
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | . | O | X | . | . | O | . |
# | X | X | O | O | . | X | . |
# | X | O | O | X | . | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.074   -0.345  -0.333  -0.408  -0.159
# Visit counts are:   891     2       3       3       6
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | O | O | X | . | . | O | . |
# | X | X | O | O | . | X | . |
# | X | O | O | X | . | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.183  -0.080  -0.049  -0.194  -0.064
# Visit counts are:   65      302     481     38      27
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | O | . | . | . | O | . |
# | . | X | . | . | . | X | . |
# | O | O | X | X | . | O | . |
# | X | X | O | O | . | X | . |
# | X | O | O | X | . | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.808  -0.066  0.077   -0.649  -0.193
# Visit counts are:   19      4       949     16      8
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | O | . | . | . | O | . |
# | . | X | . | O | . | X | . |
# | O | O | X | X | . | O | . |
# | X | X | O | O | . | X | . |
# | X | O | O | X | . | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.501  -0.521  -0.065  -0.524  -0.223
# Visit counts are:   11      18      938     6       2
# Selecting action 3
# +---+---+---+---+---+---+---+
# | . | O | . | X | . | O | . |
# | . | X | . | O | . | X | . |
# | O | O | X | X | . | O | . |
# | X | X | O | O | . | X | . |
# | X | O | O | X | . | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.046   0.021   0.092   -0.025
# Visit counts are:   223     53      577     122
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | O | . | X | . | O | . |
# | . | X | . | O | . | X | . |
# | O | O | X | X | . | O | . |
# | X | X | O | O | . | X | . |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.080  -0.121  -0.067  -0.131
# Visit counts are:   335     115     644     9
# Selecting action 4
# +---+---+---+---+---+---+---+
# | . | O | . | X | . | O | . |
# | . | X | . | O | . | X | . |
# | O | O | X | X | . | O | . |
# | X | X | O | O | X | X | . |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.072   -0.003  0.047   -0.003
# Visit counts are:   239     1       1030    1
# Selecting action 0
# +---+---+---+---+---+---+---+
# | . | O | . | X | . | O | . |
# | O | X | . | O | . | X | . |
# | O | O | X | X | . | O | . |
# | X | X | O | O | X | X | . |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.009  -0.259  -0.065  -0.974
# Visit counts are:   1367    41      205     1
# Selecting action 0
# +---+---+---+---+---+---+---+
# | X | O | . | X | . | O | . |
# | O | X | . | O | . | X | . |
# | O | O | X | X | . | O | . |
# | X | X | O | O | X | X | . |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.013   0.009   0.005
# Visit counts are:   421     553     1130
# Selecting action 2
# +---+---+---+---+---+---+---+
# | X | O | . | X | . | O | . |
# | O | X | O | O | . | X | . |
# | O | O | X | X | . | O | . |
# | X | X | O | O | X | X | . |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.002  0.001   -0.112
# Visit counts are:   4480    378     62
# Selecting action 4
# +---+---+---+---+---+---+---+
# | X | O | . | X | . | O | . |
# | O | X | O | O | . | X | . |
# | O | O | X | X | X | O | . |
# | X | X | O | O | X | X | . |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.205  -0.001  0.006
# Visit counts are:   1       6766    494
# Selecting action 6
# +---+---+---+---+---+---+---+
# | X | O | . | X | . | O | . |
# | O | X | O | O | . | X | . |
# | O | O | X | X | X | O | . |
# | X | X | O | O | X | X | O |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.001  -0.001  -0.000
# Visit counts are:   3684    336     5217
# Selecting action 6
# +---+---+---+---+---+---+---+
# | X | O | . | X | . | O | . |
# | O | X | O | O | . | X | . |
# | O | O | X | X | X | O | X |
# | X | X | O | O | X | X | O |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.064  -0.000  0.001
# Visit counts are:   5       10939   1945
# Selecting action 6
# +---+---+---+---+---+---+---+
# | X | O | . | X | . | O | . |
# | O | X | O | O | . | X | O |
# | O | O | X | X | X | O | X |
# | X | X | O | O | X | X | O |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.000  -0.001  0.000
# Visit counts are:   9463    179     9109
# Selecting action 6
# +---+---+---+---+---+---+---+
# | X | O | . | X | . | O | X |
# | O | X | O | O | . | X | O |
# | O | O | X | X | X | O | X |
# | X | X | O | O | X | X | O |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.000  -0.000
# Visit counts are:   284     23936
# Selecting action 4
# +---+---+---+---+---+---+---+
# | X | O | . | X | . | O | X |
# | O | X | O | O | O | X | O |
# | O | O | X | X | X | O | X |
# | X | X | O | O | X | X | O |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  -0.000  -0.000
# Visit counts are:   25746   884
# Selecting action 2
# +---+---+---+---+---+---+---+
# | X | O | X | X | . | O | X |
# | O | X | O | O | O | X | O |
# | O | O | X | X | X | O | X |
# | X | X | O | O | X | X | O |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: NONE
# Selecting greedy action from posterior values
# Action values are:  0.000
# Visit counts are:   29744
# Selecting action 4
# +---+---+---+---+---+---+---+
# | X | O | X | X | O | O | X |
# | O | X | O | O | O | X | O |
# | O | O | X | X | X | O | X |
# | X | X | O | O | X | X | O |
# | X | O | O | X | O | O | X |
# | X | X | O | X | O | X | O |
# +---+---+---+---+---+---+---+
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 |
# +---+---+---+---+---+---+---+
# Game result is: DRAW
